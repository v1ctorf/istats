# %%
import pandas as pd

# %%
df = pd.read_excel('Indicators_NUTS3_Level_Gender_ed.2022.xlsx')

# %%
df.head()
# Out:
#   DOMINIO                INDICATORE  SESSO TERRITORIO  \
# 0  Health  Life expectancy at birth  Males   Piemonte
# 1  Health  Life expectancy at birth  Males     Torino
# 2  Health  Life expectancy at birth  Males   Vercelli
# 3  Health  Life expectancy at birth  Males     Novara
# 4  Health  Life expectancy at birth  Males      Cuneo
#
#               UNITA_MISURA                                      FONTE V2004  \
# 0  Average number of years  Istat - Life tables of Italian population  77,6
# 1  Average number of years  Istat - Life tables of Italian population  78,2
# 2  Average number of years  Istat - Life tables of Italian population  76,2
# 3  Average number of years  Istat - Life tables of Italian population  77,5
# 4  Average number of years  Istat - Life tables of Italian population  77,7
#
#   V2005 V2006 V2007  ... V2014 V2015 V2016 V2017 V2018 V2019 V2020 V2021  \
# 0  77,9  78,2  78,5  ...  80,3  79,9  80,6  80,4  80,5  80,7  79,1  80,1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14631 entries, 0 to 14630
# Data columns (total 26 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   DOMINIO       14631 non-null  object
#  1   INDICATORE    14631 non-null  object
#  2   SESSO         14631 non-null  object
#  3   TERRITORIO    14631 non-null  object
#  4   UNITA_MISURA  14631 non-null  object
#  5   FONTE         14631 non-null  object
#  6   V2004         14631 non-null  object
#  7   V2005         14631 non-null  object
#  8   V2006         14631 non-null  object
#  9   V2007         14631 non-null  object
#  10  V2008         14631 non-null  object
#  11  V2009         14631 non-null  object
#  12  V2010         14631 non-null  object
#  13  V2011         14631 non-null  object
#  14  V2012         14631 non-null  object
#  15  V2013         14631 non-null  object
#  16  V2014         14631 non-null  object
#  17  V2015         14631 non-null  object
# ...

# %%
df_metadata = pd.read_excel('Metadata_ed.2022.xlsx')

# %%
df_metadata['Indicator'].unique()
# Out:
# array(['Life expectancy at birth', 'Avoidable mortality (age 0-74)',
#        'Infant mortality rate',
#        'Road accidents mortality rate (15-34 years old)',
#        'Age-standardised cancer mortality rate (20-64 years old)',
#        'Age-standardised mortality rate for dementia and nervous system diseases (65 years and over)',
#        'Children who benefited of early childhood services',
#        'Participation in the school system of children aged 4-5',
#        'People with at least upper secondary education level (25-64 years old)',
#        'People having completed tertiary education (ISCED 5, 6, 7 or 8)',
#        'First-time entry rate to university by cohort of upper secondary graduates',
#        'People not in education, employment, or training (NEET)',
#        'Participation in life-long learning',
#        'Inadequate level of numeracy (students in grade 8)',
#        'Inadequate level of literacy (students in grade 8)\n',
# ...
